# %%
import json

# Path to the JSON file
file_path = 'data.json'

# Read the JSON file
with open(file_path, 'r') as file:
    data = json.load(file)

# %%
data[0]
# Out:
# {'audioID': '5d44c_EN-OL-RC-538_2',
#  'audioPath': 'audios/5d44c_EN-OL-RC-538_2.wav',
#  'metaData': {'speakerID': '5d44c',
#   'gender': 'Male',
#   'grade': '5',
#   'storyID': 'EN-OL-RC-538',
#   'paragraphID': '2'},
#  'manualTranscript': 'SIL if you look at the pictures SIL of butterflies you will SIL find that many of them have large black circles on their wings SIL this look likes eyes these eyes BR are very useful ON to the butterfly SIL they help SIL it to escape from its enemies a bird SIL of a लिजा्ड SIL which is trying to catch SIL a butterfly mistakes the these black circles ON for the क्रे क्रेचर ON eyes it aims to ties SIL to hit the eye but all that SIL he it gets it SIL a bit of the wings SIL',
# ...

# %%
# get audioPath for one example

data[0]['audioPath']
# Out:
# 'audios/5d44c_EN-OL-RC-538_2.wav'

# %%
# get metadata for one example
data[0]['metaData']
# Out:
# {'speakerID': '5d44c',
#  'gender': 'Male',
#  'grade': '5',
#  'storyID': 'EN-OL-RC-538',
#  'paragraphID': '2'}

# %%
# get textAlignment

data[0]['textAlignment']
# Out:
# [{'promptTextWord': 'if', 'manualTranscriptWord': 'if', 'miscueLabel': 'c'},
#  {'promptTextWord': 'you', 'manualTranscriptWord': 'you', 'miscueLabel': 'c'},
#  {'promptTextWord': 'look',
#   'manualTranscriptWord': 'look',
#   'miscueLabel': 'c'},
#  {'promptTextWord': 'at', 'manualTranscriptWord': 'at', 'miscueLabel': 'c'},
#  {'promptTextWord': '<eps>',
#   'manualTranscriptWord': 'the',
#   'miscueLabel': 'i'},
#  {'promptTextWord': 'pictures',
#   'manualTranscriptWord': 'pictures',
#   'miscueLabel': 'c'},
#  {'promptTextWord': 'of', 'manualTranscriptWord': 'of', 'miscueLabel': 'c'},
#  {'promptTextWord': 'butterflies',
#   'manualTranscriptWord': 'butterflies',
#   'miscueLabel': 'c'},
#  {'promptTextWord': 'you', 'manualTranscriptWord': 'you', 'miscueLabel': 'c'},
#  {'promptTextWord': 'will',
#   'manualTranscriptWord': 'will',
#   'miscueLabel': 'c'},
#  {'promptTextWord': 'find',
#   'manualTranscriptWord': 'find',
#   'miscueLabel': 'c'},
#  {'promptTextWord': 'that',
# ...

# %%
data[0]['textAlignment'][0]  #first word miscue Label
# Out:
# {'promptTextWord': 'if', 'manualTranscriptWord': 'if', 'miscueLabel': 'c'}

# %%
data[0]['textAlignment'][-1]  #Last word miscue Label
# Out:
# {'promptTextWord': 'wing', 'manualTranscriptWord': 'wings', 'miscueLabel': 's'}
